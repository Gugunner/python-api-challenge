# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import time
import csv
import os
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city.title())

# Print the city count to confirm sufficient count
cities = set(cities);
cities = list(cities);
print(cities)
print(len(cities))
# Out:
# ['Upernavik', 'Wilmington', 'Bengkulu', 'Afua', 'Aguimes', 'Cururupu', 'Grand Gaube', 'Amderma', 'Altos Del Rosario', 'Constitucion', 'Abbeville', 'Port Keats', 'Beterou', 'Saint-Augustin', 'Heihe', 'Hervey Bay', 'Horki', 'Nuuk', 'Cape Town', 'Lodja', 'Novo Aripuana', 'Nanortalik', 'Neiafu', 'Zhangye', 'Port-Cartier', 'Ribeira Grande', 'Winneba', 'Bilibino', 'East London', 'San Jeronimo', 'Tignoan', 'Pangnirtung', 'Bandarbeyla', 'Kinchil', 'Sao Filipe', 'Provideniya', 'Port Moresby', 'Morros', 'Berlevag', 'Makaha', 'Zyryanovsk', 'Marrakesh', 'Chicama', 'Ozernovskiy', 'Prince Rupert', 'Lamu', 'Hobart', 'Bosaso', 'Bambous Virieux', 'Safaga', 'Sept-Iles', 'Karpushikha', 'Oyama', 'Mitu', 'Robertsport', 'Qaanaaq', 'Kot Samaba', 'Carutapera', 'Chuy', 'Liverpool', 'Pumiao', 'Cidreira', 'Sentyabrskiy', 'Araouane', 'Louisbourg', 'Richards Bay', 'Agadez', 'Spremberg', 'Oranjemund', 'Margate', 'Ojinaga', 'Lebu', 'Carnarvon', 'Komsomolskiy', 'Mar Del Plata', 'Ancud', 'Torres', 'Ahome', 'Qinhuangdao', 'Rumphi', 'Sharan', 'Bilma', 'Te Anau', 'Grafton', 'North Bend', 'Temaraia', 'Kizilskoye', 'Kananga', 'Ponta Do Sol', 'Faanui', 'Acapulco', 'Kutum', 'College', 'Bulgan', 'Saskylakh', 'Tuktoyaktuk', 'Santa Rosa', 'Limoeiro Do Norte', 'Porto Velho', 'Banepa', 'Takoradi', 'General Higinio Morinigo', 'Touros', 'Rorvik', 'Adana', 'Gorom-Gorom', 'Chiang Klang', 'Del Rio', 'Owando', 'Samalaeulu', 'Lavrentiya', 'Morro Bay', 'Ossora', 'Nguiu', 'Jeremie', 'Hamilton', 'Kollam', 'Douentza', 'Oskarshamn', 'Altay', 'Khatanga', 'Setermoen', 'Mitsamiouli', 'Chokurdakh', 'Meadow Lake', 'La Macarena', 'Pandan', 'Tsalka', 'Cabedelo', 'Kirakira', 'Pineto', 'Ixtapa', 'Pyinmana', 'Hastings', 'Grand River South East', 'Tabiauea', 'Sharon', 'Touho', 'Kapit', 'Tabou', 'Poum', 'Concepcion', 'Korla', 'Dubai', 'Lhokseumawe', 'Verkhoyansk', 'Bereda', 'Shingu', 'Illoqqortoormiut', 'Newport', 'Tiksi', 'Nemuro', 'Pineville', 'Linqiong', 'Aleksandrovsk-Sakhalinskiy', 'Corowa', 'Sabang', 'Ahuimanu', 'Attawapiskat', 'Jizan', 'La Ronge', 'Cockburn Town', 'Vaitape', 'Wanderlandia', 'Auki', 'Praia', 'Santa Fe', 'Dudinka', 'Fayaoue', 'San Cristobal', 'Kosonsoy', 'Intipuca', 'Leningradskiy', 'Mariakani', 'Avera', 'Imeni Poliny Osipenko', 'Bluff', 'Ozgon', 'Mehamn', 'Karratha', 'Palauig', 'Saint-Raymond', 'Belushya Guba', 'Hualmay', 'Bredasdorp', 'Arlit', 'Douglas', 'Santiago Del Estero', 'Bur Gabo', 'Vozhd Proletariata', 'Garissa', 'Nago', 'Chapais', 'Kaitangata', 'Kapaa', 'Katsuura', 'Devgarh', 'Halifax', 'Egvekinot', 'Narsaq', 'Puerto Ayora', 'Yabelo', 'Zhezkazgan', 'Menongue', 'Faya', 'Whitecourt', 'Cadereyta', 'Seoul', 'Port Alfred', 'Zaysan', 'Harper', 'Zheleznodorozhnyy', 'Castro', 'Dolbeau', 'Yerbogachen', 'Clifton', 'Namatanai', 'Volovo', 'Byron Bay', 'Mugur-Aksy', 'Sorland', 'Mount Gambier', 'Atuona', 'Tual', 'Beitbridge', 'Barrow', 'Rincon', 'Pishin', 'Nikolskoye', 'Sitka', 'Sembe', 'Strezhevoy', 'Jatai', 'Mount Isa', 'Barentsburg', 'Rudnya', 'Roebourne', 'San-Pedro', 'Solovetskiy', 'Manadhoo', 'Toucheng', 'Satitoa', 'Marawi', 'Belaya Gora', 'Padang', 'Atbasar', 'Umm Kaddadah', 'Yulara', 'Sao Joao Dos Patos', 'Luwuk', 'Labuhan', 'De Haan', 'Kailua', 'Shache', 'Pringsewu', 'Teknaf', 'Guaratingueta', 'Oppdal', 'Westport', 'Busselton', 'Hibbing', 'Mys Shmidta', 'Kalmunai', 'Saldanha', 'Pajarito', 'Aklavik', 'Biak', 'Vigrestad', 'Saryshagan', 'Victoria', 'Muroto', 'Arman', 'Alugan', 'Duluth', 'Ngunguru', 'Airai', 'Ndele', 'Turukhansk', 'Ornskoldsvik', 'Buala', 'Husavik', 'New Norfolk', 'Ardakan', 'Saint George', 'Tsihombe', 'Sangar', 'Sakaiminato', 'Kharagpur', 'Marcona', 'Toliary', 'Erenhot', 'Green Valley', 'Punganuru', 'Olden', 'Shar', 'Kaberamaido', 'Tumut', 'Umm Lajj', 'El Sauzal', 'Hilo', 'Vostok', 'Praia Da Vitoria', 'Cabo San Lucas', 'Paris', 'Owerri', 'Pemangkat', 'Lincoln', 'Westpunt', 'Sorong', 'Lumphat', 'Mahibadhoo', 'Norman Wells', 'Borodino', 'Kasongo', 'Iskateley', 'Kinablangan', 'Kahului', 'Huilong', 'Saint-Francois', 'Buin', 'Karatuzskoye', 'Zapolyarnyy', 'K ...
# 580

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
cities_df = pd.DataFrame({
    "City": cities,
    'Latitude': '',
    'Longitude': '',
    'Temperature': '',
    'Humidity': '',
    'Cloudiness': '',
    'Wind Speed': '',
})

print(cities_df.shape)
cities_df.head()
# Out:
# (580, 7)
#          City Latitude Longitude Temperature Humidity Cloudiness Wind Speed
# 0   Upernavik
# 1  Wilmington
# 2    Bengkulu
# 3        Afua
# 4     Aguimes

# %%
ow_query_url = "http://api.openweathermap.org/data/2.5/weather?"
params = {
    'appid': weather_api_key,
}



for (idx, row) in cities_df.iterrows():
    city = row['City']
    params['q'] = city
    ow_city_response = requests.get(ow_query_url, params=params).json()
    try:
        # print(f'Requesting data from City {city} and number {idx}')
        cities_df.loc[idx, 'Latitude'] = ow_city_response['coord']['lat'];
        cities_df.loc[idx, 'Longitude'] = ow_city_response['coord']['lon'];
        cities_df.loc[idx, 'Temperature'] = ow_city_response['main']['temp'];
        cities_df.loc[idx, 'Humidity'] = ow_city_response['main']['humidity'];
        cities_df.loc[idx, 'Cloudiness'] = ow_city_response['clouds']['all'];
        cities_df.loc[idx, 'Wind Speed'] = ow_city_response['wind']['speed'];
    except:
        print(f'Requesting data from City {city} and number {idx} failed')
    # print('--------------------------------------------------------------')
# Out:
# Requesting data from City Amderma and number 7 failed
# Requesting data from City Sentyabrskiy and number 62 failed
# Requesting data from City Louisbourg and number 64 failed
# Requesting data from City Temaraia and number 85 failed
# Requesting data from City Samalaeulu and number 109 failed
# Requesting data from City Nguiu and number 113 failed
# Requesting data from City Grand River South East and number 134 failed
# Requesting data from City Tabiauea and number 135 failed
# Requesting data from City Illoqqortoormiut and number 148 failed
# Requesting data from City Attawapiskat and number 158 failed
# Requesting data from City Wanderlandia and number 163 failed
# Requesting data from City Ozgon and number 177 failed
# Requesting data from City Belushya Guba and number 182 failed
# Requesting data from City Bur Gabo and number 188 failed
# Requesting data from City Vozhd Proletariata and number 189 failed
# Requesting data from City Dolbeau and number 213 failed
# Requesting data from City Barentsburg and number 234 failed
# Requesting data from City Solovetskiy and number 238 failed
# Requesting data from City Satitoa and number 241 failed
# Requesting data from City Mys Shmidta and number 261 failed
# Requesting data from City Saryshagan and number 268 failed
# Requesting data from City Tsihombe and number 284 failed
# Requesting data from City Marcona and number 288 failed
# Requesting data from City Toliary and number 289 failed
# Requesting data from City Westpunt and number 307 failed
# Requesting data from City Mouzakion and number 331 failed
# Requesting data from City Umzimvubu and number 351 failed
# Requesting data from City Hihifo and number 376 failed
# Requesting data from City Chagda and number 377 failed
# Requesting data from City Samusu and number 399 failed
# Requesting data from City Burica and number 415 failed
# Requesting data from City Vaitupu and number 420 failed
# Requesting data from City Sug-Aksy and number 422 failed
# Requesting data from City Cumaribo and number 424 failed
# Requesting data from City Houlung and number 470 failed
# Requesting data from City Ijaki and number 472 failed
# Requesting data from City Bokspits and number 477 failed
# Requesting data from City Taolanaro and number 489 failed
# Requesting data from City Palabuhanratu and number 495 failed
# Requesting data from City Kamenskoye and number 501 failed
# Requesting data from City Jiroft and number 514 failed
# Requesting data from City Karauzyak and number 517 failed
# Requesting data from City Longlac and number 523 failed
# Requesting data from City Tumannyy and number 535 failed
# Requesting data from City Nizhneyansk and number 544 failed
# Requesting data from City Lolua and number 571 failed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df = cities_df[cities_df['Latitude'] != '']
cities_df = cities_df.sort_values(by='City')
print(cities_df.count)
cities_df.to_csv('Cities.csv')
cities_df.head(20)
# Out:
# <bound method DataFrame.count of                   City Latitude Longitude Temperature Humidity Cloudiness  \
# 10           Abbeville     50.1      1.83       281.2       78         47
# 366         Abu Samrah     35.3     37.18      287.61       65          0
# 363          Abu Zabad    12.35     29.25      298.09       12          6
# 90            Acapulco    16.86    -99.89      304.15       55         20
# 104              Adana    36.98     35.29      289.34       93         75
# ..                 ...      ...       ...         ...      ...        ...
# 413           Zhaotong    27.32    103.72      288.21       41         32
# 211  Zheleznodorozhnyy    55.75        38      286.81       54        100
# 202         Zhezkazgan     47.8     67.71      287.83       42        100
# 456           Zhigansk    66.77    123.37      264.16       95          0
# 40          Zyryanovsk    49.74     84.27      283.06       57          0
#
#     Wind Speed
# 10        1.04
# 366        3.9
# 363       2.85
# 90         3.6
# 104        2.1
# ..         ...
# 413       0.54
# 211          3
# 202       3.41
# 456       2.49
# 40        0.49
#
# [534 rows x 7 columns]>
#                            City Latitude Longitude Temperature Humidity  \
# 10                    Abbeville     50.1      1.83       281.2       78
# 366                  Abu Samrah     35.3     37.18      287.61       65
# 363                   Abu Zabad    12.35     29.25      298.09       12
# 90                     Acapulco    16.86    -99.89      304.15       55
# 104                       Adana    36.98     35.29      289.34       93
# 452                        Aden    12.78     45.04      303.76       69
# 393                        Adre    13.47      22.2      300.23       12
# 3                          Afua    -0.16    -50.39      299.57       91
# 66                       Agadez    19.75     10.25      302.16       12
# 4                       Aguimes    27.91    -15.45      292.84       82
# 577                     Ahipara   -35.17    173.17      291.94       89
# 77                        Ahome    25.92   -109.18      307.15       14
# 157                    Ahuimanu    21.44   -157.84      299.53       57
# 275                       Airai    -8.93    125.41      287.01       71
# 418                        Akil    20.25    -89.35      309.16       32
# 265                     Aklavik    68.22   -135.01      267.15       67
# 559                        Aksu    41.12     80.26      293.59       25
# 326                      Albany     42.6    -73.97      294.36       28
# 154  Aleksandrovsk-Sakhalinskiy     50.9    142.16      275.62       82
# 576                       Alofi   -19.06   -169.92      299.15       88
#
#     Cloudiness Wind Speed
# 10          47       1.04
# 366          0        3.9
# 363          6       2.85
# 90          20        3.6
# 104         75        2.1
# 452         96        1.9
# 393        100       2.86
# 3           52       1.93
# 66           0        1.5
# 4           20        5.1
# 577        100       8.71
# 77          20        5.7
# 157         90        6.2
# 275         32       1.73
# 418        100       3.29
# 265         75        5.7
# 559        100       1.83
# 326         75        6.2
# 154         24       4.54
# 576         75        4.1

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
temperature = cities_df['Temperature']
latitude = cities_df['Latitude'];
colors = list(cities_df['Temperature'])
plt.scatter(latitude, temperature, c=colors)
plt.title("Temperature (F) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel('Temperature (F)')
clb = plt.colorbar()
clb.set_label('Temperature (F)')
plt.savefig('lat_vs_temp.png')
plt.show()

# %% [markdown]
# > We can see that temperature rises as we get closer to the center of the equator and decreases as we reach each pole.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
humidity = cities_df['Humidity']
latitude = cities_df['Latitude'];
colors = list(cities_df['Humidity'])
plt.scatter(latitude, humidity, c=colors)
plt.title("Humidity (%) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel('Humidity (%)')
clb = plt.colorbar()
clb.set_label('Humidity (%)')
plt.savefig('lat_vs_humid.png')
plt.show()

# %% [markdown]
# > Humidity is not dependant of the latitude. We should check for other factors.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloudiness = cities_df['Cloudiness']
latitude = cities_df['Latitude'];
colors = list(cities_df['Cloudiness'])
plt.scatter(latitude, cloudiness, c=colors)
plt.title("Cloudiness (%) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel('Cloudiness (%)')
clb = plt.colorbar()
clb.set_label('Cloudiness (%)')
plt.savefig('lat_vs_cloudy.png')
plt.show()

# %% [markdown]
# > There is no relation between cloudiness and latitude, as each latitude can have different cloudiness.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind_speed = cities_df['Wind Speed']
latitude = cities_df['Latitude'];
colors = list(cities_df['Wind Speed'])
plt.scatter(latitude, wind_speed, c=colors)
plt.title("Wind Speed (mph) vs Latitude")
plt.xlabel("Latitude")
plt.ylabel('Wind Speed (mph)')
clb = plt.colorbar()
clb.set_label('Wind Speed (mph)')
plt.savefig('lat_vs_wind_spd.png')
plt.show()

# %% [markdown]
# > The wind speed in our sample is pointing that a los of cities have weak wind speed values.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linearRegressionPlot(x_values, y_values, xlabel: str, ylabel: str):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))
    regress_values = x_values*slope + intercept
    colors = list(y_values)
    line_eq = f'y = {str(round(slope,2))} + x + {str(round(intercept,2))}'
    plt.scatter(x_values, y_values, c=colors)
    plt.plot(x_values, regress_values, 'r-')
    plt.annotate(line_eq,(x_values.mean(),y_values.mean()), fontsize=15,color='red')
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.title(f'{ylabel} vs. {xlabel}')
    clb = plt.colorbar()
    clb.set_label(ylabel)
    return plt;

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere_df = cities_df[cities_df['Latitude'] >= 0]
northern_hemisphere_df = northern_hemisphere_df.sort_values(by='Latitude')
southern_hemisphere_df = cities_df[cities_df['Latitude'] < 0]
southern_hemisphere_df = southern_hemisphere_df.sort_values(by='Latitude')

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
northern_temperature = northern_hemisphere_df['Temperature']
northern_latitude = northern_hemisphere_df['Latitude']

plt = linearRegressionPlot(northern_latitude, northern_temperature, 'Latitude', 'Temperature (F)')
plt.savefig('northern_lat_vs_temp.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
southern_temperature = southern_hemisphere_df['Temperature']
southern_latitude = southern_hemisphere_df['Latitude']

plt = linearRegressionPlot(southern_latitude, southern_temperature, 'Latitude', 'Temperature (F)')
plt.savefig('southern_lat_vs_temp.png')
plt.show()

# %% [markdown]
# > Plot one shows a negative strong correlation because the northern hemisphere gets colder as we reach the northern pole.
# > Plot two shows a positive strong correlation that increases temperature as we get closer to the meridian of greenwich

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
northern_humidity = northern_hemisphere_df['Humidity']
northern_latitude = northern_hemisphere_df['Latitude']

plt = linearRegressionPlot(northern_latitude, northern_humidity, 'Latitude', 'Humidity (%)')
plt.savefig('northern_lat_vs_humid.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
southern_humidity = southern_hemisphere_df['Humidity']
southern_latitude = southern_hemisphere_df['Latitude']

plt = linearRegressionPlot(southern_latitude, southern_humidity, 'Latitude', 'Humidity (%)')
plt.savefig('southern_lat_vs_humid.png')
plt.show()

# %% [markdown]
# > Plot one is similar to plot two as both have a near 0 value pearson coefficient which further proves that neither hemisphere latitude influences humidity.
# > We got a sample where a lot of northern hemisphere cities have more humidity.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
northern_cloudiness = northern_hemisphere_df['Cloudiness']
northern_latitude = northern_hemisphere_df['Latitude']

plt = linearRegressionPlot(northern_latitude, northern_cloudiness, 'Latitude', 'Cloudiness (%)')
plt.savefig('northern_lat_vs_cloudy.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
southern_cloudiness = southern_hemisphere_df['Cloudiness']
southern_latitude = southern_hemisphere_df['Latitude']

plt = linearRegressionPlot(southern_latitude, southern_cloudiness, 'Latitude', 'Cloudiness (%)')
plt.savefig('southern_lat_vs_cloudy.png')
plt.show()

# %% [markdown]
# > Both plots show no real correlation between cloudiness and latitude, but again as we can see and relate to the humidity plots we have more cloudy cities in our sample.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
northern_wind_speed = northern_hemisphere_df['Wind Speed']
northern_latitude = northern_hemisphere_df['Latitude']

plt = linearRegressionPlot(northern_latitude, northern_wind_speed, 'Latitude', 'Wind Speed (mph)')
plt.savefig('northern_lat_vs_wind_spd.png')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
southern_wind_speed = southern_hemisphere_df['Wind Speed']
southern_latitude = southern_hemisphere_df['Latitude']

plt = linearRegressionPlot(southern_latitude, southern_wind_speed, 'Latitude', 'Wind Speed (mph)')
plt.savefig('southern_lat_vs_wind_spd.png')
plt.show()

# %% [markdown]
# > Both plots prove and have similar weak correlations between wind speed and latitude but the northern hemisphere has more cities with weaker wind speeds, which means that clouds don't move as much and as a consequence are mor humid cities.
